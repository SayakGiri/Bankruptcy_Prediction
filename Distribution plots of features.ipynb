# %% [markdown]
# # VISUAL INSPECTION OF THE FEATURES/PREDICTORS
# # COLUMNS 49-72
# **Debarshi Chakraborty**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from scipy import stats 
from scipy.stats import iqr
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data.csv")
df = df.rename(columns={"Bankrupt?": "Bankrupt"})
df = df.drop(df.columns[[94]], axis=1)
df.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                           0.370594
# 1         1                                           0.464291
# 2         1                                           0.426071
# 3         1                                           0.399844
# 4         1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
X = df.iloc[:,1:95]
Y = df.iloc[:,0]
Y_new = map(str, Y) 
Y_obj = pd.DataFrame(Y_new,columns= ["Bankrupt"])
Y_obj.dtypes
# Out:
# Bankrupt    object
# dtype: object

# %%
print(Y[Y==1].shape[0], Y[Y==0].shape[0])
# Out:
# 220 6599

# %%
diagram = sns.countplot(df['Bankrupt'])
diagram.set_xticklabels(['Not Bankrupt','Bankrupt'])
plt.show()

# %%
p = df[df.iloc[:,0]==True]
q = df[df.iloc[:,0]==False]

# %% [markdown]
# **Plotted the distributions for each feature for two different categories- BANKRUPT? - YES OR NO . Interpretation??????**

# %%
sns.distplot(p.iloc[:,49])
sns.distplot(q.iloc[:,49])
# Out:
# <AxesSubplot:xlabel=' Fixed Assets Turnover Frequency', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,50])
sns.distplot(q.iloc[:,50])
# Out:
# <AxesSubplot:xlabel=' Net Worth Turnover Rate (times)', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,3+48])
sns.distplot(q.iloc[:,3+48])
# Out:
# <AxesSubplot:xlabel=' Revenue per person', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,4+48])
sns.distplot(q.iloc[:,4+48])
# Out:
# <AxesSubplot:xlabel=' Operating profit per person', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,5+48])
sns.distplot(q.iloc[:,5+48])
# Out:
# <AxesSubplot:xlabel=' Allocation rate per person', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,6+48])
sns.distplot(q.iloc[:,6+48])
# Out:
# <AxesSubplot:xlabel=' Working Capital to Total Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,7+48])
sns.distplot(q.iloc[:,7+48])
# Out:
# <AxesSubplot:xlabel=' Quick Assets/Total Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,8+48])
sns.distplot(q.iloc[:,8+48])
# Out:
# <AxesSubplot:xlabel=' Current Assets/Total Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,9+48])
sns.distplot(q.iloc[:,9+48])
# Out:
# <AxesSubplot:xlabel=' Cash/Total Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,10+48])
sns.distplot(q.iloc[:,10+48])
# Out:
# <AxesSubplot:xlabel=' Quick Assets/Current Liability', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,11+48])
sns.distplot(q.iloc[:,11+48])
# Out:
# <AxesSubplot:xlabel=' Cash/Current Liability', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,12+48])
sns.distplot(q.iloc[:,12+48])
# Out:
# <AxesSubplot:xlabel=' Current Liability to Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,13+48])
sns.distplot(q.iloc[:,13+48])
# Out:
# <AxesSubplot:xlabel=' Operating Funds to Liability', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,14+48])
sns.distplot(q.iloc[:,14+48])
# Out:
# <AxesSubplot:xlabel=' Inventory/Working Capital', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,15+48])
sns.distplot(q.iloc[:,15+48])
# Out:
# <AxesSubplot:xlabel=' Inventory/Current Liability', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,16+48])
sns.distplot(q.iloc[:,16+48])
# Out:
# <AxesSubplot:xlabel=' Current Liabilities/Liability', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,17+48])
sns.distplot(q.iloc[:,17+48])
# Out:
# <AxesSubplot:xlabel=' Working Capital/Equity', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,18+48])
sns.distplot(q.iloc[:,18+48])
# Out:
# <AxesSubplot:xlabel=' Current Liabilities/Equity', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,19+48])
sns.distplot(q.iloc[:,19+48])
# Out:
# <AxesSubplot:xlabel=' Long-term Liability to Current Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,20+48])
sns.distplot(q.iloc[:,20+48])
# Out:
# <AxesSubplot:xlabel=' Retained Earnings to Total Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,21+48])
sns.distplot(q.iloc[:,21+48])
# Out:
# <AxesSubplot:xlabel=' Total income/Total expense', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,22+48])
sns.distplot(q.iloc[:,22+48])
# Out:
# <AxesSubplot:xlabel=' Total expense/Assets', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,23+48])
sns.distplot(q.iloc[:,23+48])
# Out:
# <AxesSubplot:xlabel=' Current Asset Turnover Rate', ylabel='Density'>

# %%
sns.distplot(p.iloc[:,24+48])
sns.distplot(q.iloc[:,24+48])
# Out:
# <AxesSubplot:xlabel=' Quick Asset Turnover Rate', ylabel='Density'>

# %%
df[df['Bankrupt']==1].iloc[:,49:72].hist(figsize=(20,20),bins=25)
# Out:
# array([[<AxesSubplot:title={'center':' Fixed Assets Turnover Frequency'}>,
#         <AxesSubplot:title={'center':' Net Worth Turnover Rate (times)'}>,
#         <AxesSubplot:title={'center':' Revenue per person'}>,
#         <AxesSubplot:title={'center':' Operating profit per person'}>,
#         <AxesSubplot:title={'center':' Allocation rate per person'}>],
#        [<AxesSubplot:title={'center':' Working Capital to Total Assets'}>,
#         <AxesSubplot:title={'center':' Quick Assets/Total Assets'}>,
#         <AxesSubplot:title={'center':' Current Assets/Total Assets'}>,
#         <AxesSubplot:title={'center':' Cash/Total Assets'}>,
#         <AxesSubplot:title={'center':' Quick Assets/Current Liability'}>],
#        [<AxesSubplot:title={'center':' Cash/Current Liability'}>,
#         <AxesSubplot:title={'center':' Current Liability to Assets'}>,
#         <AxesSubplot:title={'center':' Operating Funds to Liability'}>,
# ...

# %%
df[df['Bankrupt']==0].iloc[:,49:72].hist(figsize=(20,20),bins=25)
# Out:
# array([[<AxesSubplot:title={'center':' Fixed Assets Turnover Frequency'}>,
#         <AxesSubplot:title={'center':' Net Worth Turnover Rate (times)'}>,
#         <AxesSubplot:title={'center':' Revenue per person'}>,
#         <AxesSubplot:title={'center':' Operating profit per person'}>,
#         <AxesSubplot:title={'center':' Allocation rate per person'}>],
#        [<AxesSubplot:title={'center':' Working Capital to Total Assets'}>,
#         <AxesSubplot:title={'center':' Quick Assets/Total Assets'}>,
#         <AxesSubplot:title={'center':' Current Assets/Total Assets'}>,
#         <AxesSubplot:title={'center':' Cash/Total Assets'}>,
#         <AxesSubplot:title={'center':' Quick Assets/Current Liability'}>],
#        [<AxesSubplot:title={'center':' Cash/Current Liability'}>,
#         <AxesSubplot:title={'center':' Current Liability to Assets'}>,
#         <AxesSubplot:title={'center':' Operating Funds to Liability'}>,
# ...

# %%
columns = data.columns.tolist()
for col in columns[0:]:
    f,axes = plt.subplots(1,2,figsize=(12,4))
    sns.kdeplot(x=data[col],ax=axes[0])
    sns.boxplot(x=data[col],ax=axes[1])
    f.suptitle(col)
    plt.show()

# %%
fig, axes = plt.subplots(8,3,figsize=(18,30)) # create figure and axes
for i,el in enumerate(list(df.columns.values)[49:72]):
    a = df.boxplot(el, by="Bankrupt", ax=axes.flatten()[i])
    
plt.subplots_adjust(hspace=1, wspace=0.4)
plt.show()
