# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data=pd.read_csv('data.csv')
data.head()
# Out:
#    Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0          1                                           0.370594
# 1          1                                           0.464291
# 2          1                                           0.426071
# 3          1                                           0.399844
# 4          1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
data=data.rename(columns={'Bankrupt?':'Bankrupt'})
data.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                           0.370594
# 1         1                                           0.464291
# 2         1                                           0.426071
# 3         1                                           0.399844
# 4         1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
norm_data=(data-data.mean())/data.std()
norm_data['Bankrupt']=data['Bankrupt']
norm_data.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                          -2.217747
# 1         1                                          -0.673779
# 2         1                                          -1.303576
# 3         1                                          -1.735759
# 4         1                                          -0.661729
#
#     ROA(A) before interest and % after tax  \
# 0                                -2.045648
# 1                                -0.311045
# 2                                -0.908353
# 3                                -1.636089
# 4                                -0.307722
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                          -2.400185
# 1                                          -0.598406
# 2                                          -1.319813
# 3                                          -1.556226
# ...

# %%
norm_data.isnull().sum()
# Out:
# Bankrupt                                                       0
#  ROA(C) before interest and depreciation before interest       0
#  ROA(A) before interest and % after tax                        0
#  ROA(B) before interest and depreciation after tax             0
#  Operating Gross Margin                                        0
#                                                             ...
#  Liability to Equity                                           0
#  Degree of Financial Leverage (DFL)                            0
#  Interest Coverage Ratio (Interest expense to EBIT)            0
#  Net Income Flag                                            6819
#  Equity to Liability                                           0
# Length: 96, dtype: int64

# %%
norm_data=norm_data.dropna(axis=1)
norm_data.shape
# Out:
# (6819, 95)

# %%
"""def pbc(X):
    from scipy import stats
    Y=data.iloc[:,0]
    p=stats.pointbiserialr(X,Y)[0]
    return p
# Out:
#   File "<ipython-input-7-18d9612442d7>", line 5
#     return p
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
""""corr=[]
for i in range (1,95):
    X=norm_data.iloc[:,i]
    corr.append(pbc(X))
Features=norm_data.iloc[:,1:96]
pbc_df=pd.DataFrame(Features.columns,columns=['Features'])
pbc_df['PBC']=corr
pbc_df['Abs_PBC']=np.abs(corr)
pbc_df

# %%
#pbc_df.sort_values(by=['Abs_PBC'],ascending = False).head(20)

# %%
df_freq=pd.DataFrame(norm_data['Bankrupt'].value_counts())
ax=sns.barplot(x=df_freq.index,y='Bankrupt',data=df_freq)
plt.xlabel('Bankrupt')
plt.ylabel('Frequency')
print(norm_data['Bankrupt'].value_counts())
# Out:
# 0    6599
# 1     220
# Name: Bankrupt, dtype: int64

# %% [markdown]
# Note : Here we see that our data is imbalanced , which in turn results in low correlation of the predictors with our target variable.

# %%
data[data['Bankrupt']==1].iloc[:,24:48].hist(figsize=(20,20), color='purple',edgecolor= 'white', bins = 25)
#[x.title.set_size(8) for x in fig.ravel()]
plt.show()

# %%
data[data['Bankrupt']==0].iloc[:,24:48].hist(figsize=(20,20), color='blue',edgecolor= 'white', bins = 25)
#[x.title.set_size(8) for x in fig.ravel()]
plt.show()

# %%
fig, axes = plt.subplots(8,3,figsize=(18,30)) # create figure and axes
for i,el in enumerate(list(data.columns.values)[24:48]):
    a = data.boxplot(el, by="Bankrupt", ax=axes.flatten()[i])
plt.subplots_adjust(hspace=1, wspace=0.4)
plt.show()
