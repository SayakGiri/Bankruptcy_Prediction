# %% [markdown]
# ## Generating New Data to check effectiveness of the model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from scipy import stats 
from scipy.stats import iqr
import seaborn as sns
from imblearn.over_sampling import SMOTE
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("data.csv")
df = df.rename(columns={"Bankrupt?": "Bankrupt"})
df = df.drop(df.columns[[94]], axis=1)
df.head()
# Out:
#    Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0         1                                           0.370594
# 1         1                                           0.464291
# 2         1                                           0.426071
# 3         1                                           0.399844
# 4         1                                           0.465022
#
#     ROA(A) before interest and % after tax  \
# 0                                 0.424389
# 1                                 0.538214
# 2                                 0.499019
# 3                                 0.451265
# 4                                 0.538432
#
#     ROA(B) before interest and depreciation after tax  \
# 0                                           0.405750
# 1                                           0.516730
# 2                                           0.472295
# 3                                           0.457733
# ...

# %%
p=df[df['Bankrupt']==1]

# %%
q=df[df['Bankrupt']==0]

# %% [markdown]
# **Generating some new 1's**

# %%
a1=q.iloc[50:600,]
pa1=pd.concat([p,a1])

# %%
y1=pa1['Bankrupt']
x1=pa1.iloc[:,1:95]
sm = SMOTE(random_state=481)
x1, y1 = sm.fit_resample(x1, y1)

# %%
pa2=pd.DataFrame(y1,columns=['Bankrupt'])
for i in range(0,94):
    pa2[x1.columns[i]]=x1.iloc[:,i]

# %% [markdown]
# **Generating some new 0's**

# %%
q1=q.iloc[1:50,]

# %%
pq1=pd.concat([p,q1])

# %%
y2=pq1['Bankrupt']
x2=pq1.iloc[:,1:95]

# %%
sm = SMOTE(random_state=481)
x2, y2 = sm.fit_resample(x2, y2)

# %%
pq2=pd.DataFrame(y2,columns=['Bankrupt'])
for i in range(0,94):
    pq2[x2.columns[i]]=x2.iloc[:,i]

# %%
pa2 # In this dataframe the 1's are generated
# Out:
#       Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0            1                                           0.370594
# 1            1                                           0.464291
# 2            1                                           0.426071
# 3            1                                           0.399844
# 4            1                                           0.465022
# ...        ...                                                ...
# 1095         1                                           0.481085
# 1096         1                                           0.430209
# 1097         1                                           0.431240
# 1098         1                                           0.405497
# 1099         1                                           0.368894
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
pq2 # In this dataframe the 0's are generated
# Out:
#      Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0           1                                           0.370594
# 1           1                                           0.464291
# 2           1                                           0.426071
# 3           1                                           0.399844
# 4           1                                           0.465022
# ..        ...                                                ...
# 435         0                                           0.496961
# 436         0                                           0.445265
# 437         0                                           0.503484
# 438         0                                           0.478285
# 439         0                                           0.510367
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
paq=pd.concat([pa2,pq2])
paq
# Out:
#      Bankrupt   ROA(C) before interest and depreciation before interest  \
# 0           1                                           0.370594
# 1           1                                           0.464291
# 2           1                                           0.426071
# 3           1                                           0.399844
# 4           1                                           0.465022
# ..        ...                                                ...
# 435         0                                           0.496961
# 436         0                                           0.445265
# 437         0                                           0.503484
# 438         0                                           0.478285
# 439         0                                           0.510367
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# ...

# %%
paq.to_csv('mydata.csv')

# %%
paq_x=paq.iloc[:,1:95]
paq_x
# Out:
#       ROA(C) before interest and depreciation before interest  \
# 0                                             0.370594
# 1                                             0.464291
# 2                                             0.426071
# 3                                             0.399844
# 4                                             0.465022
# ..                                                 ...
# 435                                           0.496961
# 436                                           0.445265
# 437                                           0.503484
# 438                                           0.478285
# 439                                           0.510367
#
#       ROA(A) before interest and % after tax  \
# 0                                   0.424389
# 1                                   0.538214
# 2                                   0.499019
# 3                                   0.451265
# 4                                   0.538432
# ...

# %%
paq_x.to_csv('mydata1.csv')
